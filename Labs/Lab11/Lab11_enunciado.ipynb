# %% [markdown]
# # **Laboratorio 11: Pienso, luego predigo 💡**
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2025</strong></center>
#
# ### Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina

# %% [markdown]
# ### **Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Francisco Márquez
# - Nombre de alumno 2: Santiago Haberle

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Insertar Repositorio](https://github.com/fco-marquez/MDS7202_Free_Riders)

# %% [markdown]
# ## **Temas a tratar**
#
# - Reinforcement Learning
# - Large Language Models
#
# ## **Reglas:**
#
# - **Grupos de 2 personas**
# - Fecha de entrega: Entregas Martes a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria, pero se recomienda **fuertemente** asistir.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.
#
# ### **Objetivos principales del laboratorio**
#
# - Resolución de problemas secuenciales usando Reinforcement Learning
# - Habilitar un Chatbot para entregar respuestas útiles usando Large Language Models.
#
# El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `pandas`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre DataFrames.

# %% [markdown]
# ## **1. Reinforcement Learning (2.0 puntos)**
#
# En esta sección van a usar métodos de RL para resolver dos problemas interesantes: `Blackjack` y `LunarLander`.

# %%
# !pip install -qqq gymnasium stable_baselines3
# !pip install -qqq swig
# !pip install -qqq gymnasium[box2d]

# %% [markdown]
# ### **1.1 Blackjack (1.0 puntos)**
#
# <p align="center">
#   <img src="https://www.recreoviral.com/wp-content/uploads/2016/08/s3.amazonaws.com-Math.gif"
# " width="400">
# </p>
#
# La idea de esta subsección es que puedan implementar métodos de RL y así generar una estrategia para jugar el clásico juego Blackjack y de paso puedan ~~hacerse millonarios~~ aprender a resolver problemas mediante RL.
#
# Comencemos primero preparando el ambiente. El siguiente bloque de código transforma las observaciones del ambiente a `np.array`:

# %%
import gymnasium as gym
from gymnasium.spaces import MultiDiscrete
import numpy as np

class FlattenObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super(FlattenObservation, self).__init__(env)
        self.observation_space = MultiDiscrete(np.array([32, 11, 2]))

    def observation(self, observation):
        return np.array(observation).flatten()

# Create and wrap the environment
env = gym.make("Blackjack-v1")
env = FlattenObservation(env)

# %% [markdown]
# #### **1.1.1 Descripción de MDP (0.2 puntos)**
#
# Entregue una breve descripción sobre el ambiente [Blackjack](https://gymnasium.farama.org/environments/toy_text/blackjack/) y su formulación en MDP, distinguiendo de forma clara y concisa los estados, acciones y recompensas.

# %% [markdown]
# ### Estados
# -

# %% [markdown]
# #### **1.1.2 Generando un Baseline (0.2 puntos)**
#
# Simule un escenario en donde se escojan acciones aleatorias. Repita esta simulación 5000 veces y reporte el promedio y desviación de las recompensas. ¿Cómo calificaría el performance de esta política? ¿Cómo podría interpretar las recompensas obtenidas?

# %% [markdown]
# #### **1.1.3 Entrenamiento de modelo (0.2 puntos)**
#
# A partir del siguiente [enlace](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html), escoja un modelo de `stable_baselines3` y entrenelo para resolver el ambiente `Blackjack`.

# %% [markdown]
# #### **1.1.4 Evaluación de modelo (0.2 puntos)**
#
# Repita el ejercicio 1.1.2 pero utilizando el modelo entrenado. ¿Cómo es el performance de su agente? ¿Es mejor o peor que el escenario baseline?

# %% [markdown]
# #### **1.1.5 Estudio de acciones (0.2 puntos)**
#
# Genere una función que reciba un estado y retorne la accion del agente. Luego, use esta función para entregar la acción escogida frente a los siguientes escenarios:
#
# - Suma de cartas del agente es 6, dealer muestra un 7, agente no tiene tiene un as
# - Suma de cartas del agente es 19, dealer muestra un 3, agente tiene tiene un as
#
# ¿Son coherentes sus acciones con las reglas del juego?
#
# Hint: ¿A que clase de python pertenecen los estados? Pruebe a usar el método `.reset` para saberlo.

# %% [markdown]
# ### **1.2 LunarLander**
#
# <p align="center">
#   <img src="https://i.redd.it/097t6tk29zf51.jpg"
# " width="400">
# </p>
#
# Similar a la sección 2.1, en esta sección usted se encargará de implementar una gente de RL que pueda resolver el ambiente `LunarLander`.
#
# Comencemos preparando el ambiente:

# %%
import gymnasium as gym
env = gym.make("LunarLander-v2", render_mode = "rgb_array", continuous = True) # notar el parámetro continuous = True

# %% [markdown]
# Noten que se especifica el parámetro `continuous = True`. ¿Que implicancias tiene esto sobre el ambiente?
#
# Además, se le facilita la función `export_gif` para el ejercicio 2.2.4:

# %%
import imageio
import numpy as np

def export_gif(model, n = 5):
  '''
  función que exporta a gif el comportamiento del agente en n episodios
  '''
  images = []
  for episode in range(n):
    obs = model.env.reset()
    img = model.env.render()
    done = False
    while not done:
      images.append(img)
      action, _ = model.predict(obs)
      obs, reward, done, info = model.env.step(action)
      img = model.env.render(mode="rgb_array")

  imageio.mimsave("agent_performance.gif", [np.array(img) for i, img in enumerate(images) if i%2 == 0], fps=29)

# %% [markdown]
# #### **1.2.1 Descripción de MDP (0.2 puntos)**
#
# Entregue una breve descripción sobre el ambiente [LunarLander](https://gymnasium.farama.org/environments/box2d/lunar_lander/) y su formulación en MDP, distinguiendo de forma clara y concisa los estados, acciones y recompensas. ¿Como se distinguen las acciones de este ambiente en comparación a `Blackjack`?
#
# Nota: recuerde que se especificó el parámetro `continuous = True`

# %% [markdown]
# `escriba su respuesta acá`

# %% [markdown]
# #### **1.2.2 Generando un Baseline (0.2 puntos)**
#
# Simule un escenario en donde se escojan acciones aleatorias. Repita esta simulación 10 veces y reporte el promedio y desviación de las recompensas. ¿Cómo calificaría el performance de esta política?

# %% [markdown]
# #### **1.2.3 Entrenamiento de modelo (0.2 puntos)**
#
# A partir del siguiente [enlace](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html), escoja un modelo de `stable_baselines3` y entrenelo para resolver el ambiente `LunarLander` **usando 10000 timesteps de entrenamiento**.

# %% [markdown]
# #### **1.2.4 Evaluación de modelo (0.2 puntos)**
#
# Repita el ejercicio 1.2.2 pero utilizando el modelo entrenado. ¿Cómo es el performance de su agente? ¿Es mejor o peor que el escenario baseline?

# %% [markdown]
# #### **1.2.5 Optimización de modelo (0.2 puntos)**
#
# Repita los ejercicios 1.2.3 y 1.2.4 hasta obtener un nivel de recompensas promedio mayor a 50. Para esto, puede cambiar manualmente parámetros como:
# - `total_timesteps`
# - `learning_rate`
# - `batch_size`
#
# Una vez optimizado el modelo, use la función `export_gif` para estudiar el comportamiento de su agente en la resolución del ambiente y comente sobre sus resultados.
#
# Adjunte el gif generado en su entrega (mejor aún si además adjuntan el gif en el markdown).

# %% [markdown]
# ## **2. Large Language Models (4.0 puntos)**
#
# En esta sección se enfocarán en habilitar un Chatbot que nos permita responder preguntas útiles a través de LLMs.

# %% [markdown]
# ### **2.0 Configuración Inicial**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/uqAs9atZH58AAAAd/config-config-issue.gif"
# " width="400">
# </p>
#
# Como siempre, cargamos todas nuestras API KEY al entorno:

# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

if "TAVILY_API_KEY" not in os.environ:
    os.environ["TAVILY_API_KEY"] = getpass.getpass("Enter your Tavily API key: ")

# %% [markdown]
# ### **2.1 Retrieval Augmented Generation (1.5 puntos)**
#
# <p align="center">
#   <img src="https://y.yarn.co/218aaa02-c47e-4ec9-b1c9-07792a06a88f_text.gif"
# " width="400">
# </p>
#
# El objetivo de esta subsección es que habiliten un chatbot que pueda responder preguntas usando información contenida en documentos PDF a través de **Retrieval Augmented Generation.**

# %% [markdown]
# #### **2.1.1 Reunir Documentos (0 puntos)**
#
# Reuna documentos PDF sobre los que hacer preguntas siguiendo las siguientes instrucciones:
#   - 2 documentos .pdf como mínimo.
#   - 50 páginas de contenido como mínimo entre todos los documentos.
#   - Ideas para documentos: Documentos relacionados a temas académicos, laborales o de ocio. Aprovechen este ejercicio para construir algo útil y/o relevante para ustedes!
#   - Deben ocupar documentos reales, no pueden utilizar los mismos de la clase.
#   - Deben registrar sus documentos en la siguiente [planilla](https://docs.google.com/spreadsheets/d/1Hy1w_dOiG2UCHJ8muyxhdKPZEPrrL7BNHm6E90imIIM/edit?usp=sharing). **NO PUEDEN USAR LOS MISMOS DOCUMENTOS QUE OTRO GRUPO**
#   - **Recuerden adjuntar los documentos en su entrega**.

# %%
# %pip install --upgrade --quiet PyPDF2
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import PyPDF2

BASE_DIR = os.getcwd()   # notebook working dir
print(f"Directorio base: {BASE_DIR}")
doc_base_path = os.path.join(BASE_DIR, "documentos")
# Obtener todos los PDFs dentro del directorio
doc_paths = glob.glob(os.path.join(doc_base_path, "*.pdf"))
print(f"Documentos encontrados: {doc_paths}")

assert len(doc_paths) >= 2, "Deben adjuntar un mínimo de 2 documentos"
print("Número de documentos: "+str(len(doc_paths)))

total_paginas = sum(len(PyPDF2.PdfReader(open(doc, "rb")).pages) for doc in doc_paths)
print(f"Total de páginas en los documentos: {total_paginas}")
assert total_paginas >= 50, f"Páginas insuficientes: {total_paginas}"
# Out:
# Directorio base: c:\Users\fmarq\DCC\MDS\MDS7202_Laboratorio\MDS7202_Free_Riders\Labs\Lab11
# Documentos encontrados: ['c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Demanda Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Dúplica Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Réplica Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia ASOCIACION NACIONAL DE FUTBOL PROFESIONALTURNER INTERNATIONAL LATIN AMERICA, INC - (LTE).pdf']
# Número de documentos: 5
# Total de páginas en los documentos: 58

# %% [markdown]
# #### **2.1.2 Vectorizar Documentos (0.2 puntos)**
#
# Vectorice los documentos y almacene sus representaciones de manera acorde.

# %%
# %pip install --upgrade --quiet faiss-cpu langchain_community pypdf cryptography
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import PyPDFLoader
loaders = [PyPDFLoader(path) for path in doc_paths]
documents = []
for loader in loaders:
    documents.extend(loader.load())

# %%
documents
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='Corporación de Asistencia Judicial R.M. \nCentro de Atención Jurídico y Social de San \nJoaquín. Teléfono: 5120778. \nSierra Bella 2888, Oficina 5, San \nJoaquín. sanjoaquin@cajmetro.cl \n \nEN LO PRINCIPAL:  CONTESTA DEMANDA DE NULIDAD ABSOLUTA DE \nCONTRATO E INDEMNIZACIÓN DE PERJUICIOS ; PRIMER OTROSÍ : SEÑALA \nMEDIO DE NOTIFICACIÓN ELECTRÓNICO ; SEGUNDO OTROSÍ:  MEDIOS DE \nPRUEBA; TERCER OTROSÍ:  ACOMPAÑA DOCUMENTOS ; CUARTO OTROSÍ:  \nBENEFICIO DE ASISTENCIA JUDICIAL GRATUITA  \n \nS.J.L EN LO CIVIL DE SAN MIGUEL (1º) \n  \nINGRID SORAYA GARRIDO CABELLO, abogada de la Corporación de \nAsistencia Judicial de San Joaquín, por los demandados CRISTIÁN ANDRÉS RAMOS \nALIAGA, estudiante, cédula nacional de identidad Nº20.838.865-7, domiciliado en \nThomas Alba Edison N°158, comuna de San Joaquín, Región Metropolitana, y NICOLÁS \nDANIEL RAMOS BUSTAMANTE, profesional de enfermería, cédula de identidad \nNº20.236.684-8, domiciliado en Avenida La Coruña Nº1738, Conchalí, en autos sobre \njuicio ordinario, caratulados “RAMOS/RAMO
venta del inmueble ya individualizado celebrada entre doña Guadalupe Torres \ny don Jaime Ramos, con anterioridad al fallecimiento de don Jaime Ramos, por lo que, el \ndemandante tuvo aproximadamente un periodo de un año antes del fallecimiento de l padre \nde nuestros representados  para accionar legalmente, en contra de los contratantes, \nparticularmente don Jaime Ramos que se encontraba vivo.   \n \nII. DEL DERECHO  \nEn conformidad a los artículos 1467 del Código Civil, 1707 y siguientes del Código \nCivil que regulan la simulación, y los artículos 1793 y siguientes del mismo cuerpo legal que \nregula el contrato de compraventa y de todas las demás normativas aplicables:  \n  \n1. INEXISTENCIA DE SIMULACIÓN \nEn el caso de autos no existe simulación. La simulación es la disconformidad entre la \nvoluntad real y la declarada deliberadamente querida y buscada por el autor del acto o las \npartes de la convención.  Cuestión que no ocurre en l os hechos, pues lo que se realiza es la \ntransferencia de la nuda propiedad del inmueble ya individualizado a cambio de un precio.'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 3, 'page_label': '4'}, page_content='2. CONFUSIÓN ENTRE SIMULACIÓN ABSOLUTA Y SIMULACIÓN RELATIVA \n  Yerra el articulista, debido a que confunde la simulación absoluta, en la cual  por \nesencia e l acto jurídico es ficticio en su totalidad y nada tiene de real ; con la simulación \nrelativa que su esencia es  la diferencia que media entre la voluntad que consta en la \ndeclaración y aquella que es efectivamente vinculante entre las partes, en este caso, según lo \nque sostiene erradamente la contraparte , habría una diferencia entre la especie de acto o \ncontrato que se ejecuta o celebra, es decir, existiría bajo dicho supuesto simulación relativa, \nen circunstancias que la co ntraparte deduce acción sosteniendo la existencia de simulación \nabsoluta.  \nEn efecto, en la simulación relativa el acto  simulado, es el acto declarado por las \npartes, y el disimulado u oculto, es aquel que refleja la verdadera intención de las partes y \nque se encuentra encubierto por el primero. Por una parte, se entiende que se simula algo y, \npor otra parte, se disimula. Por el contrario, en la simulación absoluta si bien, existe un acto \nsimulado, no se disimula nada.  \nEl demandante no es claro en su argumentación, confundiendo los requisitos de una \ny otra, señalando que en los hechos existiría simulación absoluta, por lo tanto debe declararse \nla nulidad absoluta por dicha razón, para después solicitar en subsidio la declaración de \nsimulación relativa y consecuente nulidad absoluta, lo que es contradictorio, pues debe \ndecidir si lo que se le imputa a los contratantes es que no tenían intención de celebrar contrato \nalguno, o por el contrario, querían realizar un acto distinto al manifestado, lo que determinará \nel objeto del juicio y los hechos a probar. \nLa misma contraparte en el líbelo de su demanda, bajo el enunciado “ Simulación \nabsoluta del contrato de compraventa -Nulidad Absoluta”, en su párrafo número 1, cita a \nnuestra Excma. Corte Suprema de Justicia, quien establece la diferencia entre simulación \nabsoluta y relativa, ejemplificando la simulación relativa  y disponiendo que  “simulación \nrelativa, cuando se ha querido realizar un acto diferente del manifestado, sea en su totalidad, \ncomo si se disfraza de compraventa una donación ”. Por tanto, esta parte no entiende por \nqué el demandante acciona respecto de una y en
),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 7, 'page_label': '8'}, page_content='Apelaciones de Santiago, en su considerando trigésimo tercero: “ Que esta manera , la \nrealidad negocial de una simulación absoluta aducida por la demandante inserta en las \ndistintas operaciones efectuadas por los demandados - compraventa del inmueble y, luego, \ncesión de las rentas de arrendamiento de un período o determinado - aparte de otros actos \nque se describen demostrativos del "animus simulandi", debe ser desestimada, pues, en el \npresente caso, no estamos frente a una simulación contractual derivada un vicio de la \ndeclaración de voluntad de los negocios jurídicos por el cual, amba s partes, de común \nacuerdo, y con el fin de obtener un resultado frente a terceros, que puede ser lícito o ilícito \n- en este caso ilícito, según la actora - dan a entender una manifestación de voluntad distinto \nde su interno querer; y menos aún se ha probado una “intención positiva de causar daños a \nterceros”, es decir, un actuar doloso, según también se ha refrendado, en sede penal, razón \npor la cual debe rechazarse la presente demanda ” (Causa nº 951/2010 (Civil). Resolución \nnº 231247 de Corte de Apelacion es de Santiago, de 27 de Diciembre de 2010 ). Cabe \nmencionar, que el demandante en su Acápite V número 16, no es preciso ni resulta entendible \na qué se refiere con “en el caso de marras, se invoca la acción de simulación para decalrar la \nexistencia de un contrato simulado, en este caso un préstamo”. En efecto, el demandante no \nindica con precisión cuál sería la eventual simulación, al aludir a un “préstamo”, una \n“donación”, “simulación absoluta” donde no habría contrato disimulado.  \n \n6. BUENA FE \nA diferencia de lo señalado en el punto anterior , uno de los principios que inspiran \ndirectamente al Código Civil y específicamente a la contratación, es el principio de la buena \nfe, la cual, en materia contractual se presume. Es del caso que, don Jaime Ramos compró la \nnuda propiedad, ya individualizada, de forma diligente y de buena fe a doña Guadalupe \nTorres, quién a su vez, vende de buena fe,  a cambio de un beneficio monetario. Por lo que \ncualquier imputación en contrario deberá probarse fehacientemente por el demandante.  \n \n7. CARGA DE LA PRUEBA  \n De acuerdo a lo dispuesto en el artículo 1698 del Código Civil, la carga de la prueba \nen orden a acreditar la concurrencia de una supuesta simulación y la nulidad consecuente y \nsu pretensión, recae en el demandante.  \n En este sentido, en un caso similar al que nos convoca, ha resuelto la Corte de \nApelaciones de San Miguel que “ Octavo: Que, correspondía a la demandante acreditar \nsuficientemente la simulación que sirve de fundamento a su demanda” (Causa nº 1618/2005 \n(Civil). Resolución nº 33527 de Corte de Apelaciones de San Miguel, de 24 de Julio de 2008).  \n Cobra especial relevancia lo dispuesto por el artículo 1709 del Código Civil, que \nconsigna “No será admisible la prueba de testigos en cuanto adicione o altere d e modo \nalguno lo que se exprese en el acto o contrato, ni sobre lo que se alegue haberse dicho antes, \no al tiempo o después de su otorgamiento”. Adicionalmente, la prueba testimonial no permite'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\
XIX, sección primera, página 37). \n5. Viciando la nulidad absoluta el acto jurídico en sí mismo, sin consideración a las personas \nque lo han celebrado, resulta lógico que pueda pedirla cualquiera persona que \ntenga interés en ello, aunque no sea parte en el acto o contrato. La excepción ya dicha \nresulta justificada como sanción, porque, como expresa un aforismo, nadie puede \naprovecharse de su propio dolo o culpa. \n6. La ley dice que puede alegar la nulidad absoluta todo el que tenga interés en ello, esto es, \ntodo el que tenga interés pecuniario en que desaparezcan los efectos del acto o \ncontrato nulo. La palabra interés se encuentra tomada en un sentido restringido, interés \npecuniario, "porque no cabe en esta materia un interés puramente moral, como es el que \nmotiva la intervención del Ministerio Público. En los proyectos, incluso el de 1853, se \ndecía que podía alegarse por todo el que tenga un interés pecuniario en ell o, pero la \nComisión Revisora prefirió la redacción que daba Delvincourt a esta exigencia sin haber \nentendido dar a la disposición un alcance más amplio que el que antes tenía. Lo único \nque el cambio puede significar es que no se requiere que el interés pue da estar \nrepresentado por una cantidad determinada". (El destacado es nuestro)  \n \nIII. SIMULACIÓN ABSOLUTA DEL CONTRATO DE COMPRAVENTA – \nNULIDAD ABSOLUTA. \n \n1. Nuestra Excma. Corte Suprema de Justicia ha establecido respecto de la simulación que: \n"Hay simulación cuando el consentimiento manifestado en un acto o contrato no \ncorresponde a la voluntad real, por lo que prácticamente pueden producirse dos clases \nde simulación: la simulación absoluta, cuando se celebra un acto jurídico que nada \ntiene de real y que es solamente ficticio en su totalidad y la simulación relativa, \ncuando se ha querido realizar un acto diferente del manifestado, sea en su \ntotalidad, como si se disfraza de compraventa una donación, sea sólo parcialmente, \ncomo si en un contrato se inserta una cláusula diferente a la convenida en verdad o se \nindica un beneficio distinto del real." (El destacado es nuestro) \n2. También se ha dicho que la simulación es la declaración de un contenido de voluntad no \nreal, emitida conscientemente y de acuerdo entre las partes, para producir con fines de \nengaño la apariencia de un negocio jurídico que no existe o es distinto de aquél que \nrealmente se ha llevado a cabo. Atendida su finalidad puede ser lícita o ilícita. \nLa primera no tiene por objeto perjudicar a terceros, no tiene un fin fraudulento. La \nsegunda en cambio, tiene por finalidad engañar a terceros, producir una mengua artificial \ndel patrimonio o su acrecentamiento ilusorio para frustrar la garantía de los acreedores e \nimpedirles que puedan satisfacer su acreencia. También puede tener por objeto al fraude \na la ley, en cuyo caso lo que se persigue es eludir una prohibición legal. \n3. En consecuencia, es necesario indicar que para que se verifique la simulación ilícita es \nmenester que concurran los siguientes elementos: a) discrepancia entre la voluntad'),
# ...
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 33, 'page_label': '34'}, page_content='derecho,  la  protección  de  los  intereses  políticos,  sociales  y \neconómicos  esenciales  del  Estado  y  el  respeto  a  las  \nobligaciones  asumidas  por  éste  con  otros  estados  u  \norganismos internacionales”;\nUndécimo:  Que  enfrentados  al  arbitrio  en  examen  \naparece que éste se funda en la supuesta inobservancia de la  \nnormas internas sobre prescripción extintiva, especialmente la  \ncontemplada en el artículo 2003 regla tercera del Código Civil y  \nen  la  transgresión  del  sistema  de  determinación  o  \ndiferenciación  de  la  culpa,  condenando  a  la  recurrente  por \nculpa grave  en el fallo arbitral de que se trata, por voto de  \nmayoría; empero, de la lectura de los reproches en comento  \nresulta que se pretende atacar más propiamente la forma en  \nque el voto de mayoría del tribunal arbitral, ha ponderado la  \nprueba  rendida  y  ha  hecho  aplicación  de  la  normativa  \ncontenida en el Código Civil. En efecto, discute la recurrente la  \ncircunstancia  de  haber  arribado  estos  juzgadores  –voto  de \nmayoría-  a  la  conclusión  que  rechazó  la  excepción  de \nprescripción  extintiva  que  esgrimió  su  parte,  y  la  \nresponsabilidad de Constructora Astaldi Cachapoal Ltda., por  \nincumplimiento de las obligaciones derivadas del contrato por  \nculpa grave, que afirma, en definitiva el voto del disidente que  \nla acción intentada se encontraba prescrita y además concluye  \nque la conducta de Astaldi no constituye culpa grave, por lo  \nque  se  debe  respetar  los  límites  de  responsabilidad  \nestablecidos en el Contrato, sin embargo, la conclusión a la que \nEZNXXFZBSLX'),
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 34, 'page_label': '35'}, page_content='llega, el voto de mayoría del Tribunal Arbitral, se encuentra  \nabsolutamente  fundado  y  sustentado  en  la  prueba,  legal, \njurisprudencia y doctrinaria que se presentó durante el proceso  \narbitral.\nCabe además indicar que respecto de la primera hipótesis  \nalegada  por  la  recurrente,  esto  es,  la  prescripción  extintiva, \nsustentada en la infracción a la regla tercera del artículo 2003  \ndel  Código  Civil,  norma  que  según  lo  desarrollado  en  el \npresente fallo, constituye una simple disposición legal que no  \nformaría parte de lo que tanto la jurisprudencia como la doctrina \nhan denominado el orden público nacional. Lo anterior debido a \nque la prescripción extintiva puede ser renunciada o modificada \npor un mero acuerdo de voluntades de las partes involucradas,  \npor  lo  cual  no  puede  formar  parte  del  concepto  de  orden \npúblico nacional, que conlleva principios fundamentales los que  \nno pueden ser alterados por las partes. Considerando además  \nque es necesario para que prospere el vicio de nulidad alegado  \npor la recurrente, que éste sea manifiesto, entendiendo por tal,  \nque sea evidente, palmario, cuestión que no sucede en el caso  \nde marras, sino que lo constatado por estos sentenciadores, es  \nla  notoria  discrepancia  a  nivel  interpretativo  de  la  referida \nnorma,  lo  que  conlleva  una  legítima  diferencia,  entre  lo \nrazonado fundadamente por el voto de mayoría del Laudo y lo  \nimpetrado por la recurrente, cuestión que no posibilita apoyar  \nsustentar una infracción de la entidad que funde debidamente  \nEZNXXFZBSLX'),
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 35, 'page_label': '36'}, page_content='un  recurso  de  nulidad  que  según  lo  ya  mencionado  \nreiteradamente por la jurisprudencia, es de derecho estricto.\nEn lo referente al segundo vicio alegado, se observa por  \nesta Corte que el voto de mayoría es claro en las motivaciones  \nque sustentan y fundan la decisión del Laudo, ésta se basa en  \nvariada  documentación  aportada  al  proceso,  sumada  a  las \ndeclaraciones e informes en derecho que posibilitan sostener  \nque  la  demandada  incumplió  sus  obligaciones  contractuales \nbajo el estándar de culpa grave. Lo anterior, no puede constituir \nuna vulneración en términos esenciales que sustente la causal  \nde nulidad basada en la infracción al orden público nacional,  \ndebido a que la culpa en el ordenamiento jurídico chileno, tiene  \nreconocimiento en el artículo 44 del Código Civil, es decir, de  \nrango meramente legal, lo que permite entonces a las partes  \npor medio del acuerdo de voluntades entre ambas modificar  \nésta, en términos de aumentar o disminuir la responsabilidad  \ncivil frente a un hecho, con excepción de la renuncia del dolo  \nfuturo,  atendido  lo  anterior,  la  culpa  no  puede  constituir  un \nprincipio  inalterable  que  permita  integrar  el  orden  público \nnacional.\nConjuntamente  con  lo  anterior,  es  necesario  mencionar \nque  la  causal  impetrada  por  la  recurrente,  adolece  de  un \nproblema  al  quedar  patente  en  el  recurso  que  la  referida \ninfracción que se alega, no es nítida, ni evidente, sino más bien  \ncorresponde a una cuestión interpretativa, por medio de la cual  \nexiste una legitima discrepancia en el razonamiento esgrimido  \nEZNXXFZBSLX'),
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 36, 'page_label': '37'}, page_content='en la sentencia impugnada y lo sostenido por el recurrente al  \nefecto,  todo  lo  cual  a  juicio  de  estos  sentenciadores,  y \nconsiderando  que  el  recurso  de  nulidad  interpuesto  es  de \nderecho estricto, permite desestimarla, ya que no satisface los  \nrequisitos  establecidos  atendida  la  naturaleza  del  recurso \nimpetrado. \nDicho lo anterior debe recordarse que e l orden público es  \nel  núcleo  del  orden  social,  compuesto  por  un  conjunto  de \naquellas características y valores de la convivencia que una  \nsociedad considera como “no negociables” y se le identifica por  \nlo  mismo  con  la  coexistencia  ordenada,  segura,  pacífica  y \nestabilizada de una sociedad. Así las cosas, el fallo que se  \npretende nulo, para entenderse viciado por la causal invocada,  \ndebe haber contrariado un orden de la magnitud de que se  \nviene hablando y no puede declararse sobre la base de un  \nestándar disminuido o de menor exigencia, so pretexto que la  \ndecisión  aqueja  a  una  de  las  partes,  máxime  si  el  mayor \nargumento es la diferencia interpretativa de normas de orden  \nmeramente legal y discutibles, según dan cuenta los sendos  \ninformes en derechos que presentaron a juicio ambos litigantes. \nPor  consiguiente  y  en  la  misma  línea  argumentativa \nprocede colegir que la mención a que se refiere en el libelo de  \nnulidad  que  se  analiza,  en  relación  con  la  transgresión  del \norden público nacional, en la medida que no se enmarca dentro \nde  aquel  sentido  que  la  doctrina  y  la  jurisprudencia  le  han \natribuido al concepto en derecho internacional privado y en la  \nEZNXXFZBSLX'),
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 37, 'page_label': '38'}, page_content='legislación chilena y comparada sobre arbitraje internacional y,  \nno se ha demostrado en definitiva que se identifique con la  \nfigura específica que describe el artículo 34 de la Ley 19.971;  \nno puede ser suficiente para justificar el reproche por el cual se  \npersigue un resultado tan gravoso como es la invalidación del  \nlaudo arbitral que se cuestiona;\nDuodécimo:  Que,  como  consecuencia,  el  denominado \nrecurso de nulidad debe ser rechazado, por cuanto no resulta  \nser, la manera o forma para procurar conseguir la revisión del  \nescrutinio que se ha verificado de las probanzas aportadas al  \njuicio arbitral, como tampoco el modo en la cual se ha aplicado  \nel derecho para la solución del conflicto, máxime si, como se  \ncolige en el caso  sub judice , se objetan los argumentos que  \nhan servido al voto de mayoría a la resolución del pleito por no  \ncompartir éstos.\nComo  se  ha  señalado,  tanto  en  doctrina  como  en  el \nderecho  comparado,  no  nos  encontramos  en  el  caso  de \nmarras, ante una segunda instancia y menos ante un recurso  \nde  casación  como  de  ningún  otro  recurso  que  tenga  por \nfinalidad u objeto examinar la conformidad a los hechos o al  \nderecho,  sino  que  se  está  ante  un  proceso  autónomo  de \nimpugnación  en  el  cual,  esta  Corte,  tiene  una  competencia \nespecífica y restrictiva, que sólo debe limitarse a resolver y  \ndejar sin efecto lo que constituye un exceso o una incorrección  \ndel  Laudo,  a  la  luz  de  los  únicos  motivos  regulados  y \nEZNXXFZBSLX'),
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 38, 'page_label': '39'}, page_content='restrictivos  que  legitiman  la  interposición  de  esta  acción  de \nnulidad en los términos señalados en la Ley 19.971.\nSe busca de esta forma que el laudo, una vez notificado  \nsea definitivo, inapelable y obligatorio para las partes, logrando  \nasí la cosa juzgada de la decisión arbitral, e impidiendo que  \nésta sea recurrible según la legislación aplicable al arbitraje, la  \ncual como ya se ha mencionado es de carácter restrictivo;\nDécimo tercero:  Que, por las consideraciones vertidas,  \nlos antecedentes y su mérito tenidos a la vista, el análisis del  \nfallo impugnado, esta Corte arriba a la convicción que el Laudo  \ndictado por el Tribunal Arbitral, no ha incurrido en el vicio de  \ninvalidación  que  se  invoca,  razón  por  la  cual  la  acción  en \nestudio procede sea desestimada.\nPor estas consideraciones y lo dispuesto en la Ley 19.971,  \nse rechaza el recurso de nulidad, deducido por el abogado don  \nFrancisco Blavi Aros, abogado, en representación convencional \nde  Constructora  Astaldi  Cachapoal  Ltda.,  en  Liquidación  y \nAstaris  SpA  (  antes  Astaldi  SpA),  ambas  del  giro  de  \nconstrucción (conjuntamente “ASTALDI”), en contra del laudo  \ndefinitivo dictado por el Tribunal Arbitral, compuesto por los  \nseñores Juan Fernández-Armesto (Presidente), Oscar Garibaldi \n(Coárbitro) y Arturo Fermandois (Coárbitro), con fecha dos de  \ndiciembre de dos mil veintiuno y corrección de fecha 28 de  \nmarzo de dos mil veintidós.\nRegístrese y archívese.\nEZNXXFZBSLX'),
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 39, 'page_label': '40'}, page_content='Redactó el señor ministro (S) Sergio Guillermo Córdova  \nAlarcón.\nNo firma el Abogado Integrante señor Peralta Anabalon, no \nobstante haber concurrido a la vista y al acuerdo del fallo, por  \nno encontrarse integrando.\nN°Civil-9442-2022.\nEZNXXFZBSLX'),
#  Document(metadata={'producer': 'OpenOffice.org 3.3; modified using iText® 5.5.0 ©2000-2013 iText Group NV (AGPL-version)', 'creator': 'Writer', 'creationdate': '2023-06-12T08:27:43-04:00', 'moddate': '2023-06-12T13:13:21-04:00', 'author': 'sec_asesoria02', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia aSTARIS spAPACIFIC HYDRO CHACAYES S.A..pdf', 'total_pages': 41, 'page': 40, 'page_label': '41'}, page_content='Pronunciado por la Segunda Sala de la Corte de Apelaciones de Santiago integrada por Ministra Maritza Elena\nVilladangos F. y Ministro Suplente Sergio Guillermo Cordova A. Santiago, doce de junio de dos mil veintitrés.\nEn Santiago, a doce de junio de dos mil veintitrés, notifiqué en Secretaría por el Estado Diario la resolución\nprecedente.\nEZNXXFZBSLX\nEste documento tiene firma electrónica y su original\npuede ser validado en http://verificadoc.pjud.cl o en la\ntramitación de la causa.\nA contar del 02 de abril de 2023, la hora visualizada\ncorresponde al horario de invierno establecido en Chile\nContinental. Para la Región de Magallanes y la Antártica\nChilena sumar una hora, mientras que para Chile Insular\nOccidental, Isla de Pascua e Isla Salas y Gómez restar\ndos horas. Para más información consulte\nhttp://www.horaoficial.cl')]

# %%
print(documents[20].page_content)
# Out:
# VI. AUSENCIA DE PRECIO: REQUISITO ESENCIAL DE LA
# COMPRAVENTA.
#
# 1. Cabe recordar S.S. que el contrato de compraventa se encuentra regulado en el
# artículo 1.793 del Código Civil, el cual reza así:
# “Art. 1793. La compraventa es un contrato en que una de las partes se obliga a dar una cosa y
# la otra a pagarla en dinero. Aquélla se dice vender y ésta comprar. El dinero que el comprador da
# por la cosa vendida, se llama precio.”
# 2. El contrato de compraventa además de los requisitos de validez de todo contrato
# como el consentimiento, capacidad, objeto y causa licita, debe contener ciertos
# elementos esenciales que le son propios, cuales son: la cosa vendida y el precio.
# 3. Por su parte, el artículo 1.801 del mismo cuerpo legal, reputa perfecta a la
# compraventa, cuando las partes han convenido en la cosa y en el precio, salvo ciertas
# excepciones, como el caso de los bienes raíces que se reputaran perfectas una vez se
# haya otorgado escritura pública y esta sea inscrita en el Conservador de Bienes Raíces
# correspondiente.
# 4. Ahora bien, corresponde ahondar en cuanto al requisito del precio de la venta, el
# cual lo encontramos en el artículo 1.808 del Código de Bello de la siguiente manera:
# “Art. 1808. El precio de la venta debe ser determinado por los contratantes. Podrá hacerse esta
# determinación por cualesquiera medios o indicaciones que lo fijen. Si se trata de cosas fungibles y se
# vende al corriente de plaza, se entenderá el del día de la entrega, a menos de expresarse otra cosa.”
# 5. El precio es el objeto de la obligación del comprador, es un elemento esencial del
# contrato de compraventa, si no hay precio no hay compraventa.
# 6. A este punto debemos detenernos y analizar los requisitos que debe tener el precio
# como elemento y requisito esencial del contrato de compraventa, el cual se compone
# de los siguientes según el autor Hernán Troncoso Larronde:
# - Debe ser pactado en dinero;
# - Debe ser real; y
# - Debe ser determinado.
# 7. En cuanto al primer requisito, cabe señalar que este debe consistir en dinero o sea
# fijado en dinero, de lo contrario puede degenerar en un contrato diverso como una
# permuta.
# 8. Ahora bien, debemos detenernos en cuanto a que el precio debe ser real, en otras
# palabras, debe ser fijado de manera que se manifieste que el vendedor tiene derecho
# a exigirlo, y el comprador la obligación de darlo.
# 9. Por tal razón, no es precio real el simulado, o que tiene por objeto disimular
# una donación.  Tampoco constituye precio el irrisorio o ridículo que no guarda
# relación con la cosa vendida, esto es, aquel que por su falta de proporción con el
# valor de la cosa vendida, pone de manifiesto que las partes no han tenido el propósito
# serio de que sea exigido.
# 10. En un contrato de compraventa, la cosa y el precio no pueden faltar jamás.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50) # inicializamos splitter
splits = text_splitter.split_documents(documents) # dividir documentos en chunks
splits[:5]
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content
pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='RAMOS, cédula nacional de identidad Nº4.080.742-K, contrajeron matrimonio.  \nMatrimonio del cual nacieron tres hijos: Don Leopoldo Manuel Ramos Torre s, \ncédula nacional de identidad Nº9.037.223 -8, nacido el día 18  de julio de 1963. Don Jaime \nElías Ramos Torres, cédula nacional de identidad Nº9.703.802 -3, nacido el día 11 de julio \nde 1964. Don Patricio Alfredo Ramos Torres, cédula nacional de identidad Nº10.521.569-\nK, nacido el día 25 de enero de 1968.')]

# %%
len(splits)
# Out:
# 341

# %%
# %pip install --upgrade --quiet  langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS

embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-001") # inicializamos los embeddings
vectorstore = FAISS.from_documents(documents=splits, embedding=embedding) # vectorizacion y almacenamiento
vectorstore
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\langchain_google_genai\embeddings.py:306, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     305 try:
# --> 306     result = self.client.batch_embed_contents(
#     307         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     308     )
#     309 except Exception as e:
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1438, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1437 # Send the request.
# -> 1438 response = rpc(
#    1439     request,
#    1440     retry=retry,
#    1441     timeout=timeout,
#    1442     metadata=metadata,
#    1443 )
#    1445 # Done; return the response.
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerProjectPerModel-FreeTier"
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[11], line 5
#       2 from langchain_community.vectorstores import FAISS
#       4 embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-001") # inicializamos los embeddings
# ----> 5 vectorstore = FAISS.from_documents(documents=splits, embedding=embedding) # vectorizacion y almacenamiento
#       6 vectorstore
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\langchain_core\vectorstores\base.py:808, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     805     if any(ids):
#     806         kwargs["ids"] = ids
# --> 808 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# File c:\Users\fmarq\miniconda3\envs\lab\Lib\site-packages\langchain_google_genai\embeddings.py:311, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     309     except Exception as e:
#     310         msg = f"Error embedding content: {e}"
# --> 311         raise GoogleGenerativeAIError(msg) from e
#     312     embeddings.extend([list(e.values) for e in result.embeddings])
#     313 return embeddings
#
# GoogleGenerativeAIError: Error embedding content: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerProjectPerModel-FreeTier"
# }
# ]

# %% [markdown]
# #### **2.1.3 Habilitar RAG (0.3 puntos)**
#
# Habilite la solución RAG a través de una *chain* y guárdela en una variable.

# %% [markdown]
# #### **2.1.4 Verificación de respuestas (0.5 puntos)**
#
# Genere un listado de 3 tuplas ("pregunta", "respuesta correcta") y analice la respuesta de su solución para cada una. ¿Su solución RAG entrega las respuestas que esperaba?
#
# Ejemplo de tupla:
# - Pregunta: ¿Quién es el presidente de Chile?
# - Respuesta correcta: El presidente de Chile es Gabriel Boric

# %% [markdown]
# #### **2.1.5 Sensibilidad de Hiperparámetros (0.5 puntos)**
#
# Extienda el análisis del punto 2.1.4 analizando cómo cambian las respuestas entregadas cambiando los siguientes hiperparámetros:
# - `Tamaño del chunk`. (*¿Cómo repercute que los chunks sean mas grandes o chicos?*)
# - `La cantidad de chunks recuperados`. (*¿Qué pasa si se devuelven muchos/pocos chunks?*)
# - `El tipo de búsqueda`. (*¿Cómo afecta el tipo de búsqueda a las respuestas de mi RAG?*)

# %% [markdown]
# ### **2.2 Agentes (1.0 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/rcqnN2aJCSEAAAAd/secret-agent-man.gif"
# " width="400">
# </p>
#
# Similar a la sección anterior, en esta sección se busca habilitar **Agentes** para obtener información a través de tools y así responder la pregunta del usuario.

# %% [markdown]
# #### **2.2.1 Tool de Tavily (0.2 puntos)**
#
# Generar una *tool* que pueda hacer consultas al motor de búsqueda **Tavily**.

# %% [markdown]
# #### **2.2.2 Tool de Wikipedia (0.2 puntos)**
#
# Generar una *tool* que pueda hacer consultas a **Wikipedia**.
#
# *Hint: Le puede ser de ayuda el siguiente [link](https://python.langchain.com/v0.1/docs/modules/tools/).*

# %% [markdown]
# #### **2.2.3 Crear Agente (0.3 puntos)**
#
# Crear un agente que pueda responder preguntas preguntas usando las *tools* antes generadas. Asegúrese que su agente responda en español. Por último, guarde el agente en una variable.

# %% [markdown]
# #### **2.2.4 Verificación de respuestas (0.3 puntos)**
#
# Pruebe el funcionamiento de su agente y asegúrese que el agente esté ocupando correctamente las tools disponibles. ¿En qué casos el agente debería ocupar la tool de Tavily? ¿En qué casos debería ocupar la tool de Wikipedia?

# %% [markdown]
# ### **2.3 Multi Agente (1.5 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/r7QMJLxU4BoAAAAd/this-is-getting-out-of-hand-star-wars.gif"
# " width="450">
# </p>
#
# El objetivo de esta subsección es encapsular las funcionalidades creadas en una solución multiagente con un **supervisor**.

# %% [markdown]
# #### **2.3.1 Generando Tools (0.5 puntos)**
#
# Transforme la solución RAG de la sección 2.1 y el agente de la sección 2.2 a *tools* (una tool por cada uno).

# %% [markdown]
# #### **2.3.2 Agente Supervisor (0.5 puntos)**
#
# Habilite un agente que tenga acceso a las tools del punto anterior y pueda responder preguntas relacionadas. Almacene este agente en una variable llamada supervisor.

# %% [markdown]
# #### **2.3.3 Verificación de respuestas (0.25 puntos)**
#
# Pruebe el funcionamiento de su agente repitiendo las preguntas realizadas en las secciones 2.1.4 y 2.2.4 y comente sus resultados. ¿Cómo varían las respuestas bajo este enfoque?

# %% [markdown]
# #### **2.3.4 Análisis (0.25 puntos)**
#
# ¿Qué diferencias tiene este enfoque con la solución *Router* vista en clases? Nombre al menos una ventaja y desventaja.

# %% [markdown]
# `escriba su respuesta acá`

# %% [markdown]
# ### **2.4 Memoria (Bonus +0.5 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/Gs95aiElrscAAAAd/memory-unlocked-ratatouille-critic.gif"
# " width="400">
# </p>
#
# Una de las principales falencias de las soluciones que hemos visto hasta ahora es que nuestro chat no responde las interacciones anteriores, por ejemplo:
#
# - Pregunta 1: "Hola! mi nombre es Sebastián"
#   - Respuesta esperada: "Hola Sebastián! ..."
# - Pregunta 2: "Cual es mi nombre?"
#   - Respuesta actual: "Lo siento pero no conozco tu nombre :("
#   - **Respuesta esperada: "Tu nombre es Sebastián"**
#
# Para solucionar esto, se les solicita agregar un componente de **memoria** a la solución entregada en el punto 2.3.
#
# **Nota: El Bonus es válido <u>sólo para la sección 2 de Large Language Models.</u>**

# %% [markdown]
# ### **2.5 Despliegue (0 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/IytHqOp52EsAAAAd/you-get-a-deploy-deploy.gif"
# " width="400">
# </p>
#
# Una vez tengan los puntos anteriores finalizados, toca la etapa de dar a conocer lo que hicimos! Para eso, vamos a desplegar nuestro modelo a través de `gradio`, una librería especializada en el levantamiento rápido de demos basadas en ML.
#
# Primero instalamos la librería:

# %%
# %pip install --upgrade --quiet gradio

# %% [markdown]
# Luego sólo deben ejecutar el siguiente código e interactuar con la interfaz a través del notebook o del link generado:

# %%
import gradio as gr
import time

def agent_response(message, history):
  '''
  Función para gradio, recibe mensaje e historial, devuelte la respuesta del chatbot.
  '''
  # get chatbot response
  response = ... # rellenar con la respuesta de su chat

  # assert
  assert type(response) == str, "output de route_question debe ser string"

  # "streaming" response
  for i in range(len(response)):
    time.sleep(0.015)
    yield response[: i+1]

gr.ChatInterface(
    agent_response,
    type="messages",
    title="Chatbot MDS7202", # Pueden cambiar esto si lo desean
    description="Hola! Soy un chatbot muy útil :)", # también la descripción
    theme="soft",
    ).launch(
        share=True, # pueden compartir el link a sus amig@s para que interactuen con su chat!
        debug = False,
        )

# %% [markdown]
# # Conclusión
# Éxito!
# <center>
# <img src ="https://media.tenor.com/MRQgxcelAV8AAAAM/perry-the-platypus-phineas-and-ferb.gif" width = 400 />
