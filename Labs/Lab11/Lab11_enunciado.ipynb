# %% [markdown]
# # **Laboratorio 11: Pienso, luego predigo 💡**
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2025</strong></center>
#
# ### Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina

# %% [markdown]
# ### **Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Francisco Márquez
# - Nombre de alumno 2: Santiago Haberle

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Insertar Repositorio](https://github.com/fco-marquez/MDS7202_Free_Riders)

# %% [markdown]
# ## **Temas a tratar**
#
# - Reinforcement Learning
# - Large Language Models
#
# ## **Reglas:**
#
# - **Grupos de 2 personas**
# - Fecha de entrega: Entregas Martes a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria, pero se recomienda **fuertemente** asistir.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.
#
# ### **Objetivos principales del laboratorio**
#
# - Resolución de problemas secuenciales usando Reinforcement Learning
# - Habilitar un Chatbot para entregar respuestas útiles usando Large Language Models.
#
# El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `pandas`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre DataFrames.

# %% [markdown]
# ## **1. Reinforcement Learning (2.0 puntos)**
#
# En esta sección van a usar métodos de RL para resolver dos problemas interesantes: `Blackjack` y `LunarLander`.

# %%
# !pip install -qqq gymnasium stable_baselines3
# !pip install -qqq swig
# !pip install -qqq gymnasium[box2d]

# %% [markdown]
# ### **1.1 Blackjack (1.0 puntos)**
#
# <p align="center">
#   <img src="https://www.recreoviral.com/wp-content/uploads/2016/08/s3.amazonaws.com-Math.gif"
# " width="400">
# </p>
#
# La idea de esta subsección es que puedan implementar métodos de RL y así generar una estrategia para jugar el clásico juego Blackjack y de paso puedan ~~hacerse millonarios~~ aprender a resolver problemas mediante RL.
#
# Comencemos primero preparando el ambiente. El siguiente bloque de código transforma las observaciones del ambiente a `np.array`:

# %%
import gymnasium as gym
from gymnasium.spaces import MultiDiscrete
import numpy as np

class FlattenObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super(FlattenObservation, self).__init__(env)
        self.observation_space = MultiDiscrete(np.array([32, 11, 2]))

    def observation(self, observation):
        return np.array(observation).flatten()

# Create and wrap the environment
env = gym.make("Blackjack-v1")
env = FlattenObservation(env)

# %% [markdown]
# #### **1.1.1 Descripción de MDP (0.2 puntos)**
#
# Entregue una breve descripción sobre el ambiente [Blackjack](https://gymnasium.farama.org/environments/toy_text/blackjack/) y su formulación en MDP, distinguiendo de forma clara y concisa los estados, acciones y recompensas.

# %% [markdown]
# ### Estados
# -

# %% [markdown]
# #### **1.1.2 Generando un Baseline (0.2 puntos)**
#
# Simule un escenario en donde se escojan acciones aleatorias. Repita esta simulación 5000 veces y reporte el promedio y desviación de las recompensas. ¿Cómo calificaría el performance de esta política? ¿Cómo podría interpretar las recompensas obtenidas?

# %% [markdown]
# #### **1.1.3 Entrenamiento de modelo (0.2 puntos)**
#
# A partir del siguiente [enlace](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html), escoja un modelo de `stable_baselines3` y entrenelo para resolver el ambiente `Blackjack`.

# %% [markdown]
# #### **1.1.4 Evaluación de modelo (0.2 puntos)**
#
# Repita el ejercicio 1.1.2 pero utilizando el modelo entrenado. ¿Cómo es el performance de su agente? ¿Es mejor o peor que el escenario baseline?

# %% [markdown]
# #### **1.1.5 Estudio de acciones (0.2 puntos)**
#
# Genere una función que reciba un estado y retorne la accion del agente. Luego, use esta función para entregar la acción escogida frente a los siguientes escenarios:
#
# - Suma de cartas del agente es 6, dealer muestra un 7, agente no tiene tiene un as
# - Suma de cartas del agente es 19, dealer muestra un 3, agente tiene tiene un as
#
# ¿Son coherentes sus acciones con las reglas del juego?
#
# Hint: ¿A que clase de python pertenecen los estados? Pruebe a usar el método `.reset` para saberlo.

# %% [markdown]
# ### **1.2 LunarLander**
#
# <p align="center">
#   <img src="https://i.redd.it/097t6tk29zf51.jpg"
# " width="400">
# </p>
#
# Similar a la sección 2.1, en esta sección usted se encargará de implementar una gente de RL que pueda resolver el ambiente `LunarLander`.
#
# Comencemos preparando el ambiente:

# %%
import gymnasium as gym
env = gym.make("LunarLander-v2", render_mode = "rgb_array", continuous = True) # notar el parámetro continuous = True

# %% [markdown]
# Noten que se especifica el parámetro `continuous = True`. ¿Que implicancias tiene esto sobre el ambiente?
#
# Además, se le facilita la función `export_gif` para el ejercicio 2.2.4:

# %%
import imageio
import numpy as np

def export_gif(model, n = 5):
  '''
  función que exporta a gif el comportamiento del agente en n episodios
  '''
  images = []
  for episode in range(n):
    obs = model.env.reset()
    img = model.env.render()
    done = False
    while not done:
      images.append(img)
      action, _ = model.predict(obs)
      obs, reward, done, info = model.env.step(action)
      img = model.env.render(mode="rgb_array")

  imageio.mimsave("agent_performance.gif", [np.array(img) for i, img in enumerate(images) if i%2 == 0], fps=29)

# %% [markdown]
# #### **1.2.1 Descripción de MDP (0.2 puntos)**
#
# Entregue una breve descripción sobre el ambiente [LunarLander](https://gymnasium.farama.org/environments/box2d/lunar_lander/) y su formulación en MDP, distinguiendo de forma clara y concisa los estados, acciones y recompensas. ¿Como se distinguen las acciones de este ambiente en comparación a `Blackjack`?
#
# Nota: recuerde que se especificó el parámetro `continuous = True`

# %% [markdown]
# `escriba su respuesta acá`

# %% [markdown]
# #### **1.2.2 Generando un Baseline (0.2 puntos)**
#
# Simule un escenario en donde se escojan acciones aleatorias. Repita esta simulación 10 veces y reporte el promedio y desviación de las recompensas. ¿Cómo calificaría el performance de esta política?

# %% [markdown]
# #### **1.2.3 Entrenamiento de modelo (0.2 puntos)**
#
# A partir del siguiente [enlace](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html), escoja un modelo de `stable_baselines3` y entrenelo para resolver el ambiente `LunarLander` **usando 10000 timesteps de entrenamiento**.

# %% [markdown]
# #### **1.2.4 Evaluación de modelo (0.2 puntos)**
#
# Repita el ejercicio 1.2.2 pero utilizando el modelo entrenado. ¿Cómo es el performance de su agente? ¿Es mejor o peor que el escenario baseline?

# %% [markdown]
# #### **1.2.5 Optimización de modelo (0.2 puntos)**
#
# Repita los ejercicios 1.2.3 y 1.2.4 hasta obtener un nivel de recompensas promedio mayor a 50. Para esto, puede cambiar manualmente parámetros como:
# - `total_timesteps`
# - `learning_rate`
# - `batch_size`
#
# Una vez optimizado el modelo, use la función `export_gif` para estudiar el comportamiento de su agente en la resolución del ambiente y comente sobre sus resultados.
#
# Adjunte el gif generado en su entrega (mejor aún si además adjuntan el gif en el markdown).

# %% [markdown]
# ## **2. Large Language Models (4.0 puntos)**
#
# En esta sección se enfocarán en habilitar un Chatbot que nos permita responder preguntas útiles a través de LLMs.

# %% [markdown]
# ### **2.0 Configuración Inicial**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/uqAs9atZH58AAAAd/config-config-issue.gif"
# " width="400">
# </p>
#
# Como siempre, cargamos todas nuestras API KEY al entorno:

# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

if "TAVILY_API_KEY" not in os.environ:
    os.environ["TAVILY_API_KEY"] = getpass.getpass("Enter your Tavily API key: ")

# %% [markdown]
# ### **2.1 Retrieval Augmented Generation (1.5 puntos)**
#
# <p align="center">
#   <img src="https://y.yarn.co/218aaa02-c47e-4ec9-b1c9-07792a06a88f_text.gif"
# " width="400">
# </p>
#
# El objetivo de esta subsección es que habiliten un chatbot que pueda responder preguntas usando información contenida en documentos PDF a través de **Retrieval Augmented Generation.**

# %% [markdown]
# #### **2.1.1 Reunir Documentos (0 puntos)**
#
# Reuna documentos PDF sobre los que hacer preguntas siguiendo las siguientes instrucciones:
#   - 2 documentos .pdf como mínimo.
#   - 50 páginas de contenido como mínimo entre todos los documentos.
#   - Ideas para documentos: Documentos relacionados a temas académicos, laborales o de ocio. Aprovechen este ejercicio para construir algo útil y/o relevante para ustedes!
#   - Deben ocupar documentos reales, no pueden utilizar los mismos de la clase.
#   - Deben registrar sus documentos en la siguiente [planilla](https://docs.google.com/spreadsheets/d/1Hy1w_dOiG2UCHJ8muyxhdKPZEPrrL7BNHm6E90imIIM/edit?usp=sharing). **NO PUEDEN USAR LOS MISMOS DOCUMENTOS QUE OTRO GRUPO**
#   - **Recuerden adjuntar los documentos en su entrega**.

# %%
# %pip install --upgrade --quiet PyPDF2
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import PyPDF2

BASE_DIR = os.getcwd()   # notebook working dir
print(f"Directorio base: {BASE_DIR}")
doc_base_path = os.path.join(BASE_DIR, "documentos")
# Obtener todos los PDFs dentro del directorio
doc_paths = glob.glob(os.path.join(doc_base_path, "*.pdf"))
print(f"Documentos encontrados: {doc_paths}")

assert len(doc_paths) >= 2, "Deben adjuntar un mínimo de 2 documentos"
print("Número de documentos: "+str(len(doc_paths)))

total_paginas = sum(len(PyPDF2.PdfReader(open(doc, "rb")).pages) for doc in doc_paths)
print(f"Total de páginas en los documentos: {total_paginas}")
assert total_paginas >= 50, f"Páginas insuficientes: {total_paginas}"
# Out:
# Directorio base: c:\Users\fmarq\DCC\MDS\MDS7202_Laboratorio\MDS7202_Free_Riders\Labs\Lab11
# Documentos encontrados: ['c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Demanda Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Dúplica Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Réplica Ramos con Ramos.pdf', 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Sentencia ASOCIACION NACIONAL DE FUTBOL PROFESIONALTURNER INTERNATIONAL LATIN AMERICA, INC - (LTE).pdf']
# Número de documentos: 5
# Total de páginas en los documentos: 58

# %% [markdown]
# #### **2.1.2 Vectorizar Documentos (0.2 puntos)**
#
# Vectorice los documentos y almacene sus representaciones de manera acorde.

# %%
# %pip install --upgrade --quiet faiss-cpu langchain_community pypdf cryptography
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import PyPDFLoader
loaders = [PyPDFLoader(path) for path in doc_paths]
documents = []
for loader in loaders:
    documents.extend(loader.load())

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50) # inicializamos splitter
splits = text_splitter.split_documents(documents) # dividir documentos en chunks
splits[:5]
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='Corporación de Asistencia Judicial R.M. \nCentro de Atención Jurídico y Social de San \nJoaquín. Teléfono: 5120778. \nSierra Bella 2888, Oficina 5, San \nJoaquín. sanjoaquin@cajmetro.cl \n \nEN LO PRINCIPAL:  CONTESTA DEMANDA DE NULIDAD ABSOLUTA DE \nCONTRATO E INDEMNIZACIÓN DE PERJUICIOS ; PRIMER OTROSÍ : SEÑALA \nMEDIO DE NOTIFICACIÓN ELECTRÓNICO ; SEGUNDO OTROSÍ:  MEDIOS DE \nPRUEBA; TERCER OTROSÍ:  ACOMPAÑA DOCUMENTOS ; CUARTO OTROSÍ:  \nBENEFICIO DE ASISTENCIA JUDICIAL GRATUITA'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='BENEFICIO DE ASISTENCIA JUDICIAL GRATUITA  \n \nS.J.L EN LO CIVIL DE SAN MIGUEL (1º) \n  \nINGRID SORAYA GARRIDO CABELLO, abogada de la Corporación de \nAsistencia Judicial de San Joaquín, por los demandados CRISTIÁN ANDRÉS RAMOS \nALIAGA, estudiante, cédula nacional de identidad Nº20.838.865-7, domiciliado en \nThomas Alba Edison N°158, comuna de San Joaquín, Región Metropolitana, y NICOLÁS \nDANIEL RAMOS BUSTAMANTE, profesional de enfermería, cédula de identidad'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='Nº20.236.684-8, domiciliado en Avenida La Coruña Nº1738, Conchalí, en autos sobre \njuicio ordinario, caratulados “RAMOS/RAMOS”, causa Rol C- 4076-2024 a S.S \nrespetuosamente digo:  \n Que por este acto y encontrándome dentro de plazo, vengo en contestar demanda de \nnulidad absoluta de contrato e indemnización de perjuicios deducida en contra  de nuestros \npatrocinados, por su tío paterno, don  Patricio Alfredo Ramos Torres , taxista, cédula de'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='identidad Nº10.521.569-K, domiciliado en calle Vasco de Gama 4596, Of. 15C, comuna Las \nCondes, por las razones de hecho y de derecho que, a continuación paso a exponer.  \n \nI. ANTECEDENTES DE HECHO \nEs efectivo que con fecha 2  de mayo de 1962, la abuela de nuestros patrocinados , \ndoña GUADALUPE DEL CARMEN TORRES POLANCO, cédula nacional de identidad \nNº4.185.202-K y el abuelo de nuestros patrocinados , don ELÍAS LEOPOLDO RAMOS'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='RAMOS, cédula nacional de identidad Nº4.080.742-K, contrajeron matrimonio.  \nMatrimonio del cual nacieron tres hijos: Don Leopoldo Manuel Ramos Torre s, \ncédula nacional de identidad Nº9.037.223 -8, nacido el día 18  de julio de 1963. Don Jaime \nElías Ramos Torres, cédula nacional de identidad Nº9.703.802 -3, nacido el día 11 de julio \nde 1964. Don Patricio Alfredo Ramos Torres, cédula nacional de identidad Nº10.521.569-\nK, nacido el día 25 de enero de 1968.')]

# %%
len(splits)
# Out:
# 341

# %%
# !pip install sentence-transformers langchain-huggingface
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (5.1.2)
# Requirement already satisfied: langchain-huggingface in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (1.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: scipy in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (1.16.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.3 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langchain-huggingface) (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.4.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (2.11.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.25.0)
# Requirement already satisfied: anyio in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (4.11.0)
# Requirement already satisfied: certifi in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain-huggingface) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\fmarq\miniconda3\envs\lab\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash", # modelo de lenguaje
    temperature=0, # probabilidad de "respuestas creativas"
    max_tokens=None, # sin tope de tokens
    timeout=None, # sin timeout
    max_retries=2, # número máximo de intentos
)

llm
# Out:
# ChatGoogleGenerativeAI(model='models/gemini-2.0-flash', google_api_key=SecretStr('**********'), temperature=0.0, max_retries=2, client=<google.ai.generativelanguage_v1beta.services.generative_service.client.GenerativeServiceClient object at 0x00000161D41DD480>, default_metadata=(), model_kwargs={})

# %%
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2") 
vectorstore = FAISS.from_documents(documents=splits, embedding=embedding) # vectorizacion y almacenamiento
vectorstore

# %% [markdown]
# #### **2.1.3 Habilitar RAG (0.3 puntos)**
#
# Habilite la solución RAG a través de una *chain* y guárdela en una variable.

# %%
retriever = vectorstore.as_retriever(search_type="similarity", # método de búsqueda
                                     search_kwargs={"k": 3}, # n° documentos a recuperar
                                     )
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000161CEB54690>, search_kwargs={'k': 3})

# %%
question = "En cuanta plata se pactó la compraventa?" # pregunta
relevant_documents = retriever.invoke(question) # top k documentos relevantes a la pregunta
relevant_documents
# Out:
# [Document(id='72b50679-f9e1-4e7b-9251-cf6b7a9a1bb2', metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 4, 'page_label': '5'}, page_content='Gonzalo Jesús Montané Wenzel , que vende, cede y transfiere la nuda propiedad del \ninmueble, que el precio de venta del inmueble es la suma de veinte millones de pesos, que el \ncomprador pagó con anterioridad, al contado, en dinero en efectivo y haber recibido el pago \na su entera satisfacción.  \nRespecto del objeto lícito , en el contrato de comp raventa, según dispone el artículo \n1793 del Código Civil, “La compraventa es un contrato en que una de las partes se obliga a'),
#  Document(id='511fedfe-1fd5-4a80-8823-76245d4b923e', metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2024-11-25T15:41:59+00:00', 'author': 'Antonia Asunción Edwards Cañas (antonia.edwards)', 'moddate': '2024-11-25T15:41:59+00:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Contestación Ramos con Ramos.pdf', 'total_pages': 9, 'page': 6, 'page_label': '7'}, page_content='puesto que, doña Guadalupe Torres declara a conciencia y según consta al suscribirse el \ncontrato de compraventa, que el precio de v enta de la nuda propiedad del inmueble \ncorresponde a la suma de veinte millones de pesos, valor que el comprador pagó con \nanterioridad, al contado, en dinero en efectivo y que lo recibió a su entera satisfacción.  \nEl acuerdo  entre las partes que concurren a la celebración del acto o contrato, es'),
#  Document(id='3cd9221d-fbfd-4055-9b68-128bba80b0cb', metadata={'producer': 'Microsoft® Word para Microsoft 365', 'creator': 'Microsoft® Word para Microsoft 365', 'creationdate': '2024-12-06T19:41:05-03:00', 'author': 'Yamir Rivera', 'moddate': '2024-12-06T19:41:05-03:00', 'source': 'c:\\Users\\fmarq\\DCC\\MDS\\MDS7202_Laboratorio\\MDS7202_Free_Riders\\Labs\\Lab11\\documentos\\Réplica Ramos con Ramos.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='pagar el precio en parcialidades durante años previos a la venta, cuestión que es un flaco favor a \nla defensa al contenido de la propia compraventa, la que indica que el pago fue al contado. \n6. Por lo demás, cabe precisar como se de mostrará en la etapa proce sal respectiva, que causante, \ndon Jaime Ramos, solo vivió con la vendedora 7 meses antes de la venta, de manera que aun en \nel caso eventual propuesto, los pagos serían significativamente alto, y no un asunto de pequeñas')]

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

print(format_docs(relevant_documents))
# Out:
# Gonzalo Jesús Montané Wenzel , que vende, cede y transfiere la nuda propiedad del
# inmueble, que el precio de venta del inmueble es la suma de veinte millones de pesos, que el
# comprador pagó con anterioridad, al contado, en dinero en efectivo y haber recibido el pago
# a su entera satisfacción.
# Respecto del objeto lícito , en el contrato de comp raventa, según dispone el artículo
# 1793 del Código Civil, “La compraventa es un contrato en que una de las partes se obliga a
#
# puesto que, doña Guadalupe Torres declara a conciencia y según consta al suscribirse el
# contrato de compraventa, que el precio de v enta de la nuda propiedad del inmueble
# corresponde a la suma de veinte millones de pesos, valor que el comprador pagó con
# anterioridad, al contado, en dinero en efectivo y que lo recibió a su entera satisfacción.
# El acuerdo  entre las partes que concurren a la celebración del acto o contrato, es
#
# pagar el precio en parcialidades durante años previos a la venta, cuestión que es un flaco favor a
# la defensa al contenido de la propia compraventa, la que indica que el pago fue al contado.
# 6. Por lo demás, cabe precisar como se de mostrará en la etapa proce sal respectiva, que causante,
# don Jaime Ramos, solo vivió con la vendedora 7 meses antes de la venta, de manera que aun en
# el caso eventual propuesto, los pagos serían significativamente alto, y no un asunto de pequeñas

# %%
retriever_chain = retriever | format_docs # chain
print(retriever_chain.invoke("Cuales son los plazos de la compraventa?"))
# Out:
# pagar el precio en parcialidades durante años previos a la venta, cuestión que es un flaco favor a
# la defensa al contenido de la propia compraventa, la que indica que el pago fue al contado.
# 6. Por lo demás, cabe precisar como se de mostrará en la etapa proce sal respectiva, que causante,
# don Jaime Ramos, solo vivió con la vendedora 7 meses antes de la venta, de manera que aun en
# el caso eventual propuesto, los pagos serían significativamente alto, y no un asunto de pequeñas
#
# determinación por cualesquiera medios o indicaciones que lo fijen. Si se trata de cosas fungibles y se
# vende al corriente de plaza, se entenderá el del día de la entrega, a menos de expresarse otra cosa.”
# 5. El precio es el objeto de la obligación del comprador, es un elemento esencial del
# contrato de compraventa, si no hay precio no hay compraventa.
# 6. A este punto debemos detenernos y analizar los requisitos que debe tener el precio
#
# de fecha 12.10.2021, y en la escritura de rectificación de fecha 04.10.2022.
# 9. Cabe mencionar, además, que la respectiva compraventa, quedó inscrita a fojas 2247 vuelta
# N°1919 correspondiente al Registro de Propiedad del año 2022 del Conservador de Bienes
# Raíces de la comuna de El Quisco.
# 10. Es relevante aclarar que la intención de doña GUADALUPE TORRES POLANCO  al
# celebrar el contrato de compraventa y constitución de usufructo era beneficiar exclusivamente a

# %%
from langchain_core.prompts import PromptTemplate

# noten como ahora existe el parámetro de context!
rag_template = '''
Eres un asistente experto en la interpretación de documentos legales.
Tu único rol es contestar preguntas del usuario a partir de información relevante que te sea proporcionada.
Responde siempre de la forma más completa posible y usando toda la información entregada.
Responde sólo lo que te pregunten a partir de la información relevante, NUNCA inventes una respuesta.

Información relevante: {context}
Pregunta: {question}
Respuesta útil:
'''

rag_prompt = PromptTemplate.from_template(rag_template)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

rag_chain = (
    {
        "context": retriever_chain, # context lo obtendremos del retriever_chain
        "question": RunnablePassthrough(), # question pasará directo hacia el prompt
    }
    | rag_prompt # prompt con las variables question y context
    | llm # llm recibe el prompt y responde
    | StrOutputParser() # recuperamos sólo la respuesta
)

question = "Cuando murió el padre?"
response = rag_chain.invoke(question)
print(response)
# Out:
# El padre, don Jaime Elías Ramos Torres, falleció el 26 de julio de 2023 en el Hospital Claudio Vicuña de la comuna de San Antonio.

# %% [markdown]
# #### **2.1.4 Verificación de respuestas (0.5 puntos)**
#
# Genere un listado de 3 tuplas ("pregunta", "respuesta correcta") y analice la respuesta de su solución para cada una. ¿Su solución RAG entrega las respuestas que esperaba?
#
# Ejemplo de tupla:
# - Pregunta: ¿Quién es el presidente de Chile?
# - Respuesta correcta: El presidente de Chile es Gabriel Boric

# %%
# Tuplas pregunta y respuesta

tuplas_qa = [
    ("Cual de los hijos de Don Elías simuló la compraventa?", "JAIME ELÍAS RAMOS TORRES."),
    ("¿Cuál es el monto total acordado en la compraventa?", "El monto total acordado en la compraventa es de $20,000,000 clp."),
    ("Cuando murió el padre de don Jaime, don elías?", "Don Jaime murió el 20 de julio de 2023, en San Antonio"),
]

for pregunta, respuesta_esperada in tuplas_qa:
    respuesta_obtenida = rag_chain.invoke(pregunta)
    print(f"Pregunta: {pregunta}")
    print(f"Respuesta obtenida: {respuesta_obtenida}")
    print(f"Respuesta esperada: {respuesta_esperada}")
    print("-" * 50)
# Out:
# Pregunta: Cual de los hijos de Don Elías simuló la compraventa?
# Respuesta obtenida: La información proporcionada no indica cuál de los hijos de Don Elías simuló la compraventa. Solo menciona que Don Jaime Ramos compró la nuda propiedad de buena fe a Doña Guadalupe Torres.
# Respuesta esperada: JAIME ELÍAS RAMOS TORRES.
# --------------------------------------------------
# Pregunta: ¿Cuál es el monto total acordado en la compraventa?
# Respuesta obtenida: El monto total acordado en la compraventa es de veinte millones de pesos.
# Respuesta esperada: El monto total acordado en la compraventa es de $20,000,000 clp.
# --------------------------------------------------
# Pregunta: Cuando murió el padre de don Jaime, don elías?
# Respuesta obtenida: La información proporcionada indica que don Jaime Elías Ramos Torres falleció el 26 de julio de 2023. No se menciona la fecha de fallecimiento de su padre, don Elías.
# Respuesta esperada: Don Jaime murió el 20 de julio de 2023, en San Antonio
# --------------------------------------------------

# %% [markdown]
# #### **2.1.5 Sensibilidad de Hiperparámetros (0.5 puntos)**
#
# Extienda el análisis del punto 2.1.4 analizando cómo cambian las respuestas entregadas cambiando los siguientes hiperparámetros:
# - `Tamaño del chunk`. (*¿Cómo repercute que los chunks sean mas grandes o chicos?*)
# - `La cantidad de chunks recuperados`. (*¿Qué pasa si se devuelven muchos/pocos chunks?*)
# - `El tipo de búsqueda`. (*¿Cómo afecta el tipo de búsqueda a las respuestas de mi RAG?*)

# %% [markdown]
# ### **2.2 Agentes (1.0 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/rcqnN2aJCSEAAAAd/secret-agent-man.gif"
# " width="400">
# </p>
#
# Similar a la sección anterior, en esta sección se busca habilitar **Agentes** para obtener información a través de tools y así responder la pregunta del usuario.

# %% [markdown]
# #### **2.2.1 Tool de Tavily (0.2 puntos)**
#
# Generar una *tool* que pueda hacer consultas al motor de búsqueda **Tavily**.

# %% [markdown]
# #### **2.2.2 Tool de Wikipedia (0.2 puntos)**
#
# Generar una *tool* que pueda hacer consultas a **Wikipedia**.
#
# *Hint: Le puede ser de ayuda el siguiente [link](https://python.langchain.com/v0.1/docs/modules/tools/).*

# %% [markdown]
# #### **2.2.3 Crear Agente (0.3 puntos)**
#
# Crear un agente que pueda responder preguntas preguntas usando las *tools* antes generadas. Asegúrese que su agente responda en español. Por último, guarde el agente en una variable.

# %% [markdown]
# #### **2.2.4 Verificación de respuestas (0.3 puntos)**
#
# Pruebe el funcionamiento de su agente y asegúrese que el agente esté ocupando correctamente las tools disponibles. ¿En qué casos el agente debería ocupar la tool de Tavily? ¿En qué casos debería ocupar la tool de Wikipedia?

# %% [markdown]
# ### **2.3 Multi Agente (1.5 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/r7QMJLxU4BoAAAAd/this-is-getting-out-of-hand-star-wars.gif"
# " width="450">
# </p>
#
# El objetivo de esta subsección es encapsular las funcionalidades creadas en una solución multiagente con un **supervisor**.

# %% [markdown]
# #### **2.3.1 Generando Tools (0.5 puntos)**
#
# Transforme la solución RAG de la sección 2.1 y el agente de la sección 2.2 a *tools* (una tool por cada uno).

# %% [markdown]
# #### **2.3.2 Agente Supervisor (0.5 puntos)**
#
# Habilite un agente que tenga acceso a las tools del punto anterior y pueda responder preguntas relacionadas. Almacene este agente en una variable llamada supervisor.

# %% [markdown]
# #### **2.3.3 Verificación de respuestas (0.25 puntos)**
#
# Pruebe el funcionamiento de su agente repitiendo las preguntas realizadas en las secciones 2.1.4 y 2.2.4 y comente sus resultados. ¿Cómo varían las respuestas bajo este enfoque?

# %% [markdown]
# #### **2.3.4 Análisis (0.25 puntos)**
#
# ¿Qué diferencias tiene este enfoque con la solución *Router* vista en clases? Nombre al menos una ventaja y desventaja.

# %% [markdown]
# `escriba su respuesta acá`

# %% [markdown]
# ### **2.4 Memoria (Bonus +0.5 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/Gs95aiElrscAAAAd/memory-unlocked-ratatouille-critic.gif"
# " width="400">
# </p>
#
# Una de las principales falencias de las soluciones que hemos visto hasta ahora es que nuestro chat no responde las interacciones anteriores, por ejemplo:
#
# - Pregunta 1: "Hola! mi nombre es Sebastián"
#   - Respuesta esperada: "Hola Sebastián! ..."
# - Pregunta 2: "Cual es mi nombre?"
#   - Respuesta actual: "Lo siento pero no conozco tu nombre :("
#   - **Respuesta esperada: "Tu nombre es Sebastián"**
#
# Para solucionar esto, se les solicita agregar un componente de **memoria** a la solución entregada en el punto 2.3.
#
# **Nota: El Bonus es válido <u>sólo para la sección 2 de Large Language Models.</u>**

# %% [markdown]
# ### **2.5 Despliegue (0 puntos)**
#
# <p align="center">
#   <img src="https://media1.tenor.com/m/IytHqOp52EsAAAAd/you-get-a-deploy-deploy.gif"
# " width="400">
# </p>
#
# Una vez tengan los puntos anteriores finalizados, toca la etapa de dar a conocer lo que hicimos! Para eso, vamos a desplegar nuestro modelo a través de `gradio`, una librería especializada en el levantamiento rápido de demos basadas en ML.
#
# Primero instalamos la librería:

# %%
# %pip install --upgrade --quiet gradio

# %% [markdown]
# Luego sólo deben ejecutar el siguiente código e interactuar con la interfaz a través del notebook o del link generado:

# %%
import gradio as gr
import time

def agent_response(message, history):
  '''
  Función para gradio, recibe mensaje e historial, devuelte la respuesta del chatbot.
  '''
  # get chatbot response
  response = ... # rellenar con la respuesta de su chat

  # assert
  assert type(response) == str, "output de route_question debe ser string"

  # "streaming" response
  for i in range(len(response)):
    time.sleep(0.015)
    yield response[: i+1]

gr.ChatInterface(
    agent_response,
    type="messages",
    title="Chatbot MDS7202", # Pueden cambiar esto si lo desean
    description="Hola! Soy un chatbot muy útil :)", # también la descripción
    theme="soft",
    ).launch(
        share=True, # pueden compartir el link a sus amig@s para que interactuen con su chat!
        debug = False,
        )

# %% [markdown]
# # Conclusión
# Éxito!
# <center>
# <img src ="https://media.tenor.com/MRQgxcelAV8AAAAM/perry-the-platypus-phineas-and-ferb.gif" width = 400 />
